# %%
import numpy as np
import pandas as pd
from copy import deepcopy
from nanoid import generate


def nano_id():
    return generate(
        '0123456789ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz',
        size=12)

# %% [markdown]
# # Total Overview

# %%
data = pd.read_csv('../resource/product_data.csv', index_col=0)
data.shape
# Out:
# (10771, 5)

# %%
data.head(10)
# Out:
#          Product ID         Category Sub-Category  \
# 0  OFF-TEN-10000025  Office Supplies      Storage
# 1   OFF-SU-10000618  Office Supplies     Supplies
# 2  OFF-TEN-10001585  Office Supplies      Storage
# 3   OFF-PA-10001492  Office Supplies        Paper
# 4   FUR-FU-10003447        Furniture  Furnishings
# 5   OFF-PA-10001968  Office Supplies        Paper
# 6   TEC-CO-10002316       Technology      Copiers
# 7   FUR-BO-10003966        Furniture    Bookcases
# 8  OFF-FEL-10001541  Office Supplies      Storage
# 9   OFF-ST-10002161  Office Supplies      Storage
#
#                                         Product Name  Unit Price
# 0                                Tenex Lockers, Blue      204.15
# 1                           Acme Trimmer, High Speed       44.58
# 2                            Tenex Box, Single Width       16.53
# 3                        Enermax Note Cards, Premium       29.91
# 4                         Eldon Light Bulb, Duo Pack       25.26
# 5            Eaton Computer Printout Paper, 8.5 x 11       30.69
# 6                     Brother Personal Copier, Laser      142.89
# 7  Sauder Facets Collection Library, Sky Alder Fi...      170.98
# 8                       Fellowes Lockers, Wire Frame      206.40
# 9                          Tenex Trays, Single Width       54.24

# %%
data = data.drop(['Product ID'], axis=1)
data = data.rename(columns={'Category': 'category_name', 'Sub-Category': 'second_category_name', 'Product Name': 'product_name', 'Unit Price': 'unit_price'})
data['category_id'] = ''
data['second_category_id'] = ''
data['third_category_id'] = ''
data['third_category_name'] = ''
data['product_id'] = ''
# data['image_url'] = ''
data = data[['product_id', 'product_name', 'category_id', 'category_name', 'second_category_id', 'second_category_name',
              'third_category_id', 'third_category_name', 'unit_price']]

# %%
data.head(10)
# Out:
#   product_id                                       product_name category_id  \
# 0                                           Tenex Lockers, Blue
# 1                                      Acme Trimmer, High Speed
# 2                                       Tenex Box, Single Width
# 3                                   Enermax Note Cards, Premium
# 4                                    Eldon Light Bulb, Duo Pack
# 5                       Eaton Computer Printout Paper, 8.5 x 11
# 6                                Brother Personal Copier, Laser
# 7             Sauder Facets Collection Library, Sky Alder Fi...
# 8                                  Fellowes Lockers, Wire Frame
# 9                                     Tenex Trays, Single Width
#
#      category_name second_category_id second_category_name third_category_id  \
# 0  Office Supplies                                 Storage
# 1  Office Supplies                                Supplies
# 2  Office Supplies                                 Storage
# 3  Office Supplies                                   Paper
# 4        Furniture                             Furnishings
# 5  Office Supplies                                   Paper
# 6       Technology                                 Copiers
# 7        Furniture                               Bookcases
# 8  Office Supplies                                 Storage
# 9  Office Supplies                                 Storage
#
#   third_category_name  unit_price
# 0                          204.15
# 1                           44.58
# 2                           16.53
# 3                           29.91
# 4                           25.26
# 5                           30.69
# 6                          142.89
# 7                          170.98
# 8                          206.40
# 9                           54.24

# %%
data['category_name'].value_counts()
# Out:
# Office Supplies    5957
# Technology         2484
# Furniture          2330
# Name: category_name, dtype: int64

# %% [markdown]
# # Office Supplies

# %%
office_supplies = deepcopy(data[data['category_name'] == 'Office Supplies'])
office_supplies.shape
# Out:
# (5957, 9)

# %%
office_supplies.head(10)
# Out:
#    product_id                                 product_name category_id  \
# 0                                      Tenex Lockers, Blue
# 1                                 Acme Trimmer, High Speed
# 2                                  Tenex Box, Single Width
# 3                              Enermax Note Cards, Premium
# 5                  Eaton Computer Printout Paper, 8.5 x 11
# 8                             Fellowes Lockers, Wire Frame
# 9                                Tenex Trays, Single Width
# 10                          KitchenAid Coffee Grinder, Red
# 11                     Hamilton Beach Refrigerator, Silver
# 13             Binney & Smith Pencil Sharpener, Easy-Erase
#
#       category_name second_category_id second_category_name third_category_id  \
# 0   Office Supplies                                 Storage
# 1   Office Supplies                                Supplies
# 2   Office Supplies                                 Storage
# 3   Office Supplies                                   Paper
# 5   Office Supplies                                   Paper
# 8   Office Supplies                                 Storage
# 9   Office Supplies                                 Storage
# 10  Office Supplies                              Appliances
# 11  Office Supplies                              Appliances
# 13  Office Supplies                                     Art
#
#    third_category_name  unit_price
# 0                           204.15
# 1                            44.58
# 2                            16.53
# 3                            29.91
# 5                            30.69
# 8                           206.40
# 9                            54.24
# 10                           70.47
# 11                          333.92
# 13                           27.93

# %%
office_supplies['second_category_name'].value_counts()
# Out:
# Paper         825
# Binders       781
# Art           708
# Storage       684
# Envelopes     613
# Labels        602
# Appliances    587
# Fasteners     583
# Supplies      574
# Name: second_category_name, dtype: int64

# %%
office_supplies.loc[:, 'category_id'] = nano_id()
office_supplies.loc[office_supplies['second_category_name'] == 'Paper', 'second_category_id'] = nano_id()
office_supplies.loc[office_supplies['second_category_name'] == 'Binders', 'second_category_id'] = nano_id()
office_supplies.loc[office_supplies['second_category_name'] == 'Art', 'second_category_id'] = nano_id()
office_supplies.loc[office_supplies['second_category_name'] == 'Storage', 'second_category_id'] = nano_id()
office_supplies.loc[office_supplies['second_category_name'] == 'Envelopes', 'second_category_id'] = nano_id()
office_supplies.loc[office_supplies['second_category_name'] == 'Labels', 'second_category_id'] = nano_id()
office_supplies.loc[office_supplies['second_category_name'] == 'Appliances', 'second_category_id'] = nano_id()
office_supplies.loc[office_supplies['second_category_name'] == 'Fasteners', 'second_category_id'] = nano_id()
office_supplies.loc[office_supplies['second_category_name'] == 'Supplies', 'second_category_id'] = nano_id()

# %%
office_supplies.head(10)
# Out:
#    product_id                                 product_name   category_id  \
# 0                                      Tenex Lockers, Blue  O8xD8rO2X816
# 1                                 Acme Trimmer, High Speed  O8xD8rO2X816
# 2                                  Tenex Box, Single Width  O8xD8rO2X816
# 3                              Enermax Note Cards, Premium  O8xD8rO2X816
# 5                  Eaton Computer Printout Paper, 8.5 x 11  O8xD8rO2X816
# 8                             Fellowes Lockers, Wire Frame  O8xD8rO2X816
# 9                                Tenex Trays, Single Width  O8xD8rO2X816
# 10                          KitchenAid Coffee Grinder, Red  O8xD8rO2X816
# 11                     Hamilton Beach Refrigerator, Silver  O8xD8rO2X816
# 13             Binney & Smith Pencil Sharpener, Easy-Erase  O8xD8rO2X816
#
#       category_name second_category_id second_category_name third_category_id  \
# 0   Office Supplies       e5a2vp9Bpczy              Storage
# 1   Office Supplies       KVraCWQHdXOj             Supplies
# 2   Office Supplies       e5a2vp9Bpczy              Storage
# 3   Office Supplies       WtzhL5cVilg6                Paper
# 5   Office Supplies       WtzhL5cVilg6                Paper
# 8   Office Supplies       e5a2vp9Bpczy              Storage
# 9   Office Supplies       e5a2vp9Bpczy              Storage
# 10  Office Supplies       hwpWTtn7Tl5o           Appliances
# 11  Office Supplies       hwpWTtn7Tl5o           Appliances
# 13  Office Supplies       iqGEIzIl1stw                  Art
#
#    third_category_name  unit_price
# 0                           204.15
# 1                            44.58
# 2                            16.53
# 3                            29.91
# 5                            30.69
# 8                           206.40
# 9                            54.24
# 10                           70.47
# 11                          333.92
# 13                           27.93

# %%
office_supplies['second_category_id'].value_counts()
# Out:
# WtzhL5cVilg6    825
# N5ccdFcsnltk    781
# iqGEIzIl1stw    708
# e5a2vp9Bpczy    684
# ZxKkOmS8NOKD    613
# oCfS4bvy1LsH    602
# hwpWTtn7Tl5o    587
# C4AwzJFyQqMN    583
# KVraCWQHdXOj    574
# Name: second_category_id, dtype: int64

# %%
def random_assign_third_category(df, second_category_name, third_category_names, p):
    if (len(third_category_names) == 0 or len(p) == 0):
        raise ValueError('third_category_name and p must be non-empty lists')
    
    if (len(third_category_names) != len(p)):
        raise ValueError('Length of third_category_name and p must be equal')
    
    print(f'Assigning third category {third_category_names} for second category, {second_category_name}\n')

    row_len = len(df[df['second_category_name'] == second_category_name])

    print(f'Number of rows for {second_category_name}: {row_len}\n')

    random_third_category = np.random.choice(third_category_names, row_len, p=p)

    df.loc[df['second_category_name'] == second_category_name, 'third_category_name'] = random_third_category

    print(df[df['second_category_name'] == second_category_name].value_counts('third_category_name'))
    print('\n')

    for third_category_name in third_category_names:
        df.loc[(df['second_category_name'] == second_category_name) & 
                (df['third_category_name'] == third_category_name), 'third_category_id'] = nano_id()

    print(df[df['second_category_name'] == second_category_name].value_counts('third_category_id'))

# %% [markdown]
# ## Paper
#
# Paper has 4 third categories: Copy & Printer Paper, Photo Paper, Colored Paper and Large Quantity Paper.

# %%
random_assign_third_category(office_supplies, 
                            'Paper',
                            ['Copy & Printer Paper', 'Photo Paper', 'Colored Paper', 'Large Quantity Paper'], 
                            [0.5, 0.2, 0.2, 0.1] )
# Out:
# Assigning third category ['Copy & Printer Paper', 'Photo Paper', 'Colored Paper', 'Large Quantity Paper'] for second category, Paper
#
# Number of rows for Paper: 825
#
# third_category_name
# Copy & Printer Paper    403
# Colored Paper           174
# Photo Paper             159
# Large Quantity Paper     89
# dtype: int64
#
#
# third_category_id
# 0V6sLr6aGtuU    403
# qqzbBdEGx2q0    174
# MXZvWPGkLDmv    159
# gi9OHivrGpvA     89
# dtype: int64

# %% [markdown]
# ## Binders
#
# Binders has 3 third categories: A4 Binders, Pocket Binders and Mini Binders.

# %%
random_assign_third_category(office_supplies,
                            'Binders',
                            ['A4 Binders', 'Pocket Binders', 'Mini Binders'],
                            [0.5, 0.3, 0.2])
# Out:
# Assigning third category ['A4 Binders', 'Pocket Binders', 'Mini Binders'] for second category, Binders
#
# Number of rows for Binders: 781
#
# third_category_name
# A4 Binders        409
# Pocket Binders    224
# Mini Binders      148
# dtype: int64
#
#
# third_category_id
# gCtco1vmTVuQ    409
# yqnCMUrXSiN3    224
# 38rg4WcUvmop    148
# dtype: int64

# %% [markdown]
# ## Art
#
# Arts has 3 third categories: Oil Paints, Drawing Ink, Chalk

# %%
random_assign_third_category(office_supplies,
                            'Art',
                            ['Oil Paints', 'Drawing Ink', 'Chalk'],
                            [0.5, 0.3, 0.2])
# Out:
# Assigning third category ['Oil Paints', 'Drawing Ink', 'Chalk'] for second category, Art
#
# Number of rows for Art: 708
#
# third_category_name
# Oil Paints     366
# Drawing Ink    195
# Chalk          147
# dtype: int64
#
#
# third_category_id
# Tt8AQ7EawiV5    366
# sEghhe5Z1x5Z    195
# 8rDeNB23qEHt    147
# dtype: int64

# %% [markdown]
# ## Storage
#
# Storage has 3 third categories: Storage Bins & Boxes, File Folders, File Storage

# %%
random_assign_third_category(office_supplies,
                            'Storage',
                            ['Storage Bins & Boxes', 'File Folders', 'File Storage'],
                            [0.4, 0.3, 0.3])
# Out:
# Assigning third category ['Storage Bins & Boxes', 'File Folders', 'File Storage'] for second category, Storage
#
# Number of rows for Storage: 684
#
# third_category_name
# Storage Bins & Boxes    270
# File Folders            225
# File Storage            189
# dtype: int64
#
#
# third_category_id
# cGAY8PSjSybf    270
# jS5eFcAuwcyS    225
# gm6nCZ8aVa3g    189
# dtype: int64

# %% [markdown]
# ## Envelopes
#
# Envelopes has 3 third categories: Business, Catalog, Security

# %%
random_assign_third_category(office_supplies,
                            'Envelopes',
                            ['Business', 'Catalog', 'Security'],
                            [0.2, 0.5, 0.3])
# Out:
# Assigning third category ['Business', 'Catalog', 'Security'] for second category, Envelopes
#
# Number of rows for Envelopes: 613
#
# third_category_name
# Catalog     292
# Security    185
# Business    136
# dtype: int64
#
#
# third_category_id
# yUwxpiq70mhM    292
# HE4b01TkSJ1p    185
# Hcw7hKx4Duob    136
# dtype: int64

# %% [markdown]
# ## Labels

# %% [markdown]
# Labels has 2 third categories: Address, Shipping, File

# %%
random_assign_third_category(office_supplies,
                            'Labels',
                            ['Address', 'Shipping', 'File'],
                            [0.6, 0.2, 0.2])
# Out:
# Assigning third category ['Address', 'Shipping', 'File'] for second category, Labels
#
# Number of rows for Labels: 602
#
# third_category_name
# Address     375
# File        117
# Shipping    110
# dtype: int64
#
#
# third_category_id
# SZidrffddp2x    375
# 4GP71kU2vHhr    117
# 1nVFuigFYNMQ    110
# dtype: int64

# %% [markdown]
# ## Appliances

# %% [markdown]
# Appliances has 1 third categories: Coffee, Water & Snacks

# %%
random_assign_third_category(office_supplies,
                            'Appliances',
                            ['Coffee, Water & Snacks'],                            
                            [1.0])
# Out:
# Assigning third category ['Coffee, Water & Snacks'] for second category, Appliances
#
# Number of rows for Appliances: 587
#
# third_category_name
# Coffee, Water & Snacks    587
# dtype: int64
#
#
# third_category_id
# LoI4lmPulhq4    587
# dtype: int64

# %% [markdown]
# ## Fasteners

# %% [markdown]
# Fasteners has 3 third categories: Clips & Fasteners, Hook and Loop Fasteners and Classification Folders

# %%
random_assign_third_category(office_supplies,
                            'Fasteners',
                            ['Clips & Fasteners', 'Hook and Loop Fasteners', 'Classification Folders'],
                            [0.3, 0.2, 0.5])
# Out:
# Assigning third category ['Clips & Fasteners', 'Hook and Loop Fasteners', 'Classification Folders'] for second category, Fasteners
#
# Number of rows for Fasteners: 583
#
# third_category_name
# Classification Folders     287
# Clips & Fasteners          180
# Hook and Loop Fasteners    116
# dtype: int64
#
#
# third_category_id
# rQn4fOmbQYV6    287
# 3u6ZiMAsyzWf    180
# uQ4KU2vUp8RA    116
# dtype: int64

# %% [markdown]
# ## Supplies
#
# Supplies has 3 third categories: Glue & Glue Sticks, Scissors and Decorative Tapes

# %%
random_assign_third_category(office_supplies,
                            'Supplies',
                            ['Glue & Glue Sticks', 'Scissors','Decorative Tapes'],
                            [0.3, 0.3, 0.4])
# Out:
# Assigning third category ['Glue & Glue Sticks', 'Scissors', 'Decorative Tapes'] for second category, Supplies
#
# Number of rows for Supplies: 574
#
# third_category_name
# Decorative Tapes      224
# Scissors              180
# Glue & Glue Sticks    170
# dtype: int64
#
#
# third_category_id
# Oj06cWFVJmoH    224
# 21WujeVWiMhJ    180
# AABy1Yj6edjQ    170
# dtype: int64

# %%
office_supplies.head(60)
# Out:
#    product_id                                       product_name  \
# 0                                            Tenex Lockers, Blue
# 1                                       Acme Trimmer, High Speed
# 2                                        Tenex Box, Single Width
# 3                                    Enermax Note Cards, Premium
# 5                        Eaton Computer Printout Paper, 8.5 x 11
# 8                                   Fellowes Lockers, Wire Frame
# 9                                      Tenex Trays, Single Width
# 10                                KitchenAid Coffee Grinder, Red
# 11                           Hamilton Beach Refrigerator, Silver
# 13                   Binney & Smith Pencil Sharpener, Easy-Erase
# 14                                    Kleencut Ruler, High Speed
# 16                         Sanford Pencil Sharpener, Water Color
# 17                     Wilson Jones Hole Reinforcements, Economy
# 18                          Smead File Folder Labels, Adjustable
# 19                            GlobeWeis Peel and Seal, Set of 50
# 20                            Acco Hole Reinforcements, Recycled
# 21                            Avery Hole Reinforcements, Durable
# 22                       Wilson Jones Hole Reinforcements, Clear
# 23                                Fellowes File Cart, Industrial
# 26                                 Hamilton Beach Toaster, Black
# 30                                Fellowes Lockers, Single Width
# 35                                          BIC Sketch Pad, Blue
# 38                               Fellowes Shelving, Single Width
# 40                                       BIC Markers, Easy-Erase
# 44                            Kraft Peel and Seal, Security-Tint
# 48                                  Smead Shelving, Single Width
# 49             Recycled Steel Personal File for Hanging File ...
# 50                                          Stanley Canvas, Blue
# 51                                        Fellowes Folders, Blue
# 52               Fellowes Bankers Box Recycled Super Stor/Drawer
# 55                                   Acco 3-Hole Punch, Recycled
# 57                                      Acme Scissors, Easy Grip
# 58                                Xerox Parchment Paper, Premium
# 59                                       Eldon Box, Single Width
# 60                                     Sanford Pens, Fluorescent
# 61                               Binney & Smith Pens, Easy-Erase
# 62                                 Fellowes Shelving, Wire Frame
# 63                                 OIC Push Pins, Assorted Sizes
# 64                           Hon Shipping Labels, 5000 Label Set
# 66                       Plymouth Boxed Rubber Bands by Plymouth
# 67             Black Print Carbonless 8 1/2" x 8 1/4" Rapid M...
# 68                    Hon Round Labels, Laser Printer Compatible
# 70                            Acco Hole Reinforcements, Recycled
# 71                       Wilson Jones Hole Reinforcements, Clear
# 72                                        Ibico Index Tab, Clear
# 73                                         Tenex Box, Wire Frame
# 74                                        Hoover Toaster, Silver
# 77                        Wilson Jones Binding Machine, Recycled
# 79                                   Stanley Canvas, Water Color
# 81                               Cardinal Binding Machine, Clear
# 82                                        Cuisinart Toaster, Red
# 87                                      Rogers Trays, Wire Frame
# 88                                   Stanley Markers, Easy-Erase
# 90                                   Smead Folders, Single Width
# 91                                                     Avery 490
# 92                                        Rogers Box, Wire Frame
# 93                         Cardinal Hole Reinforcements, Economy
# 94                     Rogers Profile Extra Capacity Storage Tub
# 95                         Cardinal Hole Reinforcements, Durable
# 96                                 Cardinal Binder Covers, Clear
#
#      category_id    category_name second_category_id second_category_name  \
# 0   O8xD8rO2X816  Office Supplies       e5a2vp9Bpczy              Storage
# 1   O8xD8rO2X816  Office Supplies       KVraCWQHdXOj             Supplies
# 2   O8xD8rO2X816  Office Supplies       e5a2vp9Bpczy              Storage
# 3   O8xD8rO2X816  Office Supplies       WtzhL5cVilg6                Paper
# 5   O8xD8rO2X816  Office Supplies       WtzhL5cVilg6                Paper
# 8   O8xD8rO2X816  Office Supplies       e5a2vp9Bpczy              Storage
# 9   O8xD8rO2X816  Office Supplies       e5a2vp9Bpczy              Storage
# 10  O8xD8rO2X816  Office Supplies       hwpWTtn7Tl5o           Appliances
# 11  O8xD8rO2X816  Office Supplies       hwpWTtn7Tl5o           Appliances
# 13  O8xD8rO2X816  Office Supplies       iqGEIzIl1stw                  Art
# 14  O8xD8rO2X816  Office Supplies       KVraCWQHdXOj             Supplies
# 16  O8xD8rO2X816  Office Supplies       iqGEIzIl1stw                  Art
# 17  O8xD8rO2X816  Office Supplies       N5ccdFcsnltk              Binders
# 18  O8xD8rO2X816  Office Supplies       oCfS4bvy1LsH               Labels
# 19  O8xD8rO2X816  Office Supplies       ZxKkOmS8NOKD            Envelopes
# 20  O8xD8rO2X816  Office Supplies       N5ccdFcsnltk              Binders
# 21  O8xD8rO2X816  Office Supplies       N5ccdFcsnltk              Binders
# 22  O8xD8rO2X816  Office Supplies       N5ccdFcsnltk              Binders
# 23  O8xD8rO2X816  Office Supplies       e5a2vp9Bpczy              Storage
# 26  O8xD8rO2X816  Office Supplies       hwpWTtn7Tl5o           Appliances
# 30  O8xD8rO2X816  Office Supplies       e5a2vp9Bpczy              Storage
# 35  O8xD8rO2X816  Office Supplies       iqGEIzIl1stw                  Art
# 38  O8xD8rO2X816  Office Supplies       e5a2vp9Bpczy              Storage
# 40  O8xD8rO2X816  Office Supplies       iqGEIzIl1stw                  Art
# 44  O8xD8rO2X816  Office Supplies       ZxKkOmS8NOKD            Envelopes
# 48  O8xD8rO2X816  Office Supplies       e5a2vp9Bpczy              Storage
# 49  O8xD8rO2X816  Office Supplies       e5a2vp9Bpczy              Storage
# 50  O8xD8rO2X816  Office Supplies       iqGEIzIl1stw                  Art
# 51  O8xD8rO2X816  Office Supplies       e5a2vp9Bpczy              Storage
# 52  O8xD8rO2X816  Office Supplies       e5a2vp9Bpczy              Storage
# 55  O8xD8rO2X816  Office Supplies       N5ccdFcsnltk              Binders
# 57  O8xD8rO2X816  Office Supplies       KVraCWQHdXOj             Supplies
# 58  O8xD8rO2X816  Office Supplies       WtzhL5cVilg6                Paper
# 59  O8xD8rO2X816  Office Supplies       e5a2vp9Bpczy              Storage
# 60  O8xD8rO2X816  Office Supplies       iqGEIzIl1stw                  Art
# 61  O8xD8rO2X816  Office Supplies       iqGEIzIl1stw                  Art
# 62  O8xD8rO2X816  Office Supplies       e5a2vp9Bpczy              Storage
# 63  O8xD8rO2X816  Office Supplies       C4AwzJFyQqMN            Fasteners
# 64  O8xD8rO2X816  Office Supplies       oCfS4bvy1LsH               Labels
# 66  O8xD8rO2X816  Office Supplies       C4AwzJFyQqMN            Fasteners
# 67  O8xD8rO2X816  Office Supplies       WtzhL5cVilg6                Paper
# 68  O8xD8rO2X816  Office Supplies       oCfS4bvy1LsH               Labels
# 70  O8xD8rO2X816  Office Supplies       N5ccdFcsnltk              Binders
# 71  O8xD8rO2X816  Office Supplies       N5ccdFcsnltk              Binders
# 72  O8xD8rO2X816  Office Supplies       N5ccdFcsnltk              Binders
# 73  O8xD8rO2X816  Office Supplies       e5a2vp9Bpczy              Storage
# 74  O8xD8rO2X816  Office Supplies       hwpWTtn7Tl5o           Appliances
# 77  O8xD8rO2X816  Office Supplies       N5ccdFcsnltk              Binders
# 79  O8xD8rO2X816  Office Supplies       iqGEIzIl1stw                  Art
# 81  O8xD8rO2X816  Office Supplies       N5ccdFcsnltk              Binders
# 82  O8xD8rO2X816  Office Supplies       hwpWTtn7Tl5o           Appliances
# 87  O8xD8rO2X816  Office Supplies       e5a2vp9Bpczy              Storage
# 88  O8xD8rO2X816  Office Supplies       iqGEIzIl1stw                  Art
# 90  O8xD8rO2X816  Office Supplies       e5a2vp9Bpczy              Storage
# 91  O8xD8rO2X816  Office Supplies       oCfS4bvy1LsH               Labels
# 92  O8xD8rO2X816  Office Supplies       e5a2vp9Bpczy              Storage
# 93  O8xD8rO2X816  Office Supplies       N5ccdFcsnltk              Binders
# 94  O8xD8rO2X816  Office Supplies       e5a2vp9Bpczy              Storage
# 95  O8xD8rO2X816  Office Supplies       N5ccdFcsnltk              Binders
# 96  O8xD8rO2X816  Office Supplies       N5ccdFcsnltk              Binders
#
#    third_category_id      third_category_name  unit_price
# 0       cGAY8PSjSybf     Storage Bins & Boxes      204.15
# 1       AABy1Yj6edjQ       Glue & Glue Sticks       44.58
# 2       cGAY8PSjSybf     Storage Bins & Boxes       16.53
# 3       0V6sLr6aGtuU     Copy & Printer Paper       29.91
# 5       0V6sLr6aGtuU     Copy & Printer Paper       30.69
# 8       jS5eFcAuwcyS             File Folders      206.40
# 9       gm6nCZ8aVa3g             File Storage       54.24
# 10      LoI4lmPulhq4   Coffee, Water & Snacks       70.47
# 11      LoI4lmPulhq4   Coffee, Water & Snacks      333.92
# 13      sEghhe5Z1x5Z              Drawing Ink       27.93
# 14      AABy1Yj6edjQ       Glue & Glue Sticks       13.56
# 16      8rDeNB23qEHt                    Chalk       26.10
# 17      gCtco1vmTVuQ               A4 Binders        4.53
# 18      SZidrffddp2x                  Address        6.78
# 19      Hcw7hKx4Duob                 Business       21.39
# 20      gCtco1vmTVuQ               A4 Binders        7.02
# 21      gCtco1vmTVuQ               A4 Binders        5.91
# 22      38rg4WcUvmop             Mini Binders        2.66
# 23      jS5eFcAuwcyS             File Folders      137.79
# 26      LoI4lmPulhq4   Coffee, Water & Snacks       56.94
# 30      cGAY8PSjSybf     Storage Bins & Boxes      207.36
# 35      Tt8AQ7EawiV5               Oil Paints       48.66
# 38      gm6nCZ8aVa3g             File Storage       57.87
# 40      sEghhe5Z1x5Z              Drawing Ink       26.70
# 44      yUwxpiq70mhM                  Catalog       22.89
# 48      jS5eFcAuwcyS             File Folders       48.96
# 49      jS5eFcAuwcyS             File Folders       57.23
# 50      Tt8AQ7EawiV5               Oil Paints       49.47
# 51      cGAY8PSjSybf     Storage Bins & Boxes       26.40
# 52      jS5eFcAuwcyS             File Folders       53.98
# 55      38rg4WcUvmop             Mini Binders       30.48
# 57      Oj06cWFVJmoH         Decorative Tapes       27.06
# 58      qqzbBdEGx2q0            Colored Paper       13.26
# 59      gm6nCZ8aVa3g             File Storage       10.29
# 60      Tt8AQ7EawiV5               Oil Paints       12.36
# 61      Tt8AQ7EawiV5               Oil Paints       12.21
# 62      cGAY8PSjSybf     Storage Bins & Boxes       56.91
# 63      3u6ZiMAsyzWf        Clips & Fasteners       12.36
# 64      4GP71kU2vHhr                     File       11.76
# 66      uQ4KU2vUp8RA  Hook and Loop Fasteners        4.71
# 67      MXZvWPGkLDmv              Photo Paper        7.28
# 68      1nVFuigFYNMQ                 Shipping        6.66
# 70      yqnCMUrXSiN3           Pocket Binders        7.02
# 71      yqnCMUrXSiN3           Pocket Binders        3.99
# 72      gCtco1vmTVuQ               A4 Binders        8.91
# 73      cGAY8PSjSybf     Storage Bins & Boxes       15.57
# 74      LoI4lmPulhq4   Coffee, Water & Snacks       84.39
# 77      38rg4WcUvmop             Mini Binders       49.32
# 79      Tt8AQ7EawiV5               Oil Paints       52.65
# 81      gCtco1vmTVuQ               A4 Binders       49.23
# 82      LoI4lmPulhq4   Coffee, Water & Snacks       35.64
# 87      cGAY8PSjSybf     Storage Bins & Boxes       40.50
# 88      Tt8AQ7EawiV5               Oil Paints       14.98
# 90      jS5eFcAuwcyS             File Folders       17.52
# 91      SZidrffddp2x                  Address       14.80
# 92      cGAY8PSjSybf     Storage Bins & Boxes       23.04
# 93      gCtco1vmTVuQ               A4 Binders        3.56
# 94      gm6nCZ8aVa3g             File Storage       16.74
# 95      gCtco1vmTVuQ               A4 Binders        4.56
# 96      yqnCMUrXSiN3           Pocket Binders        7.64

# %%
office_supplies.isnull().sum()
# Out:
# product_id              0
# product_name            0
# category_id             0
# category_name           0
# second_category_id      0
# second_category_name    0
# third_category_id       0
# third_category_name     0
# unit_price              0
# dtype: int64

# %% [markdown]
# # Furniture

# %%
furniture = deepcopy(data[data['category_name'] == 'Furniture'])
furniture.shape
# Out:
# (2330, 9)

# %%
furniture.head(10)
# Out:
#    product_id                                       product_name category_id  \
# 4                                     Eldon Light Bulb, Duo Pack
# 7              Sauder Facets Collection Library, Sky Alder Fi...
# 12                               Advantus Photo Frame, Erganomic
# 24                           Safco Classic Bookcase, Traditional
# 27                              Novimex Swivel Fabric Task Chair
# 28                             Harbour Creations Bag Chairs, Red
# 29                                Office Star Rocking Chair, Red
# 32                       Global Deluxe High-Back Manager's Chair
# 34                  Bevis Round Conference Room Tables and Bases
# 36                         Harbour Creations Steel Folding Chair
#
#    category_name second_category_id second_category_name third_category_id  \
# 4      Furniture                             Furnishings
# 7      Furniture                               Bookcases
# 12     Furniture                             Furnishings
# 24     Furniture                               Bookcases
# 27     Furniture                                  Chairs
# 28     Furniture                                  Chairs
# 29     Furniture                                  Chairs
# 32     Furniture                                  Chairs
# 34     Furniture                                  Tables
# 36     Furniture                                  Chairs
#
#    third_category_name  unit_price
# 4                            25.26
# 7                           170.98
# 12                           51.60
# 24                          438.15
# 27                          150.98
# 28                           61.62
# 29                          140.91
# 32                          285.98
# 34                          179.29
# 36                           86.25

# %%
furniture['second_category_name'].value_counts()
# Out:
# Furnishings    719
# Chairs         647
# Bookcases      583
# Tables         381
# Name: second_category_name, dtype: int64

# %%
furniture.loc[:, 'category_id'] = nano_id()
furniture.loc[furniture['second_category_name'] == 'Furnishings', 'second_category_id'] = nano_id()
furniture.loc[furniture['second_category_name'] == 'Chairs', 'second_category_id'] = nano_id()
furniture.loc[furniture['second_category_name'] == 'Bookcases', 'second_category_id'] = nano_id()
furniture.loc[furniture['second_category_name'] == 'Tables', 'second_category_id'] = nano_id()

# %%
furniture.head(10)
# Out:
#    product_id                                       product_name  \
# 4                                     Eldon Light Bulb, Duo Pack
# 7              Sauder Facets Collection Library, Sky Alder Fi...
# 12                               Advantus Photo Frame, Erganomic
# 24                           Safco Classic Bookcase, Traditional
# 27                              Novimex Swivel Fabric Task Chair
# 28                             Harbour Creations Bag Chairs, Red
# 29                                Office Star Rocking Chair, Red
# 32                       Global Deluxe High-Back Manager's Chair
# 34                  Bevis Round Conference Room Tables and Bases
# 36                         Harbour Creations Steel Folding Chair
#
#      category_id category_name second_category_id second_category_name  \
# 4   TQMnS5aEiOTt     Furniture       uJujcjmijtWM          Furnishings
# 7   TQMnS5aEiOTt     Furniture       QJq4Lp1JUP97            Bookcases
# 12  TQMnS5aEiOTt     Furniture       uJujcjmijtWM          Furnishings
# 24  TQMnS5aEiOTt     Furniture       QJq4Lp1JUP97            Bookcases
# 27  TQMnS5aEiOTt     Furniture       a90C0BfQbneg               Chairs
# 28  TQMnS5aEiOTt     Furniture       a90C0BfQbneg               Chairs
# 29  TQMnS5aEiOTt     Furniture       a90C0BfQbneg               Chairs
# 32  TQMnS5aEiOTt     Furniture       a90C0BfQbneg               Chairs
# 34  TQMnS5aEiOTt     Furniture       E2zR8n3joH68               Tables
# 36  TQMnS5aEiOTt     Furniture       a90C0BfQbneg               Chairs
#
#    third_category_id third_category_name  unit_price
# 4                                              25.26
# 7                                             170.98
# 12                                             51.60
# 24                                            438.15
# 27                                            150.98
# 28                                             61.62
# 29                                            140.91
# 32                                            285.98
# 34                                            179.29
# 36                                             86.25

# %%
furniture['second_category_id'].value_counts()
# Out:
# uJujcjmijtWM    719
# a90C0BfQbneg    647
# QJq4Lp1JUP97    583
# E2zR8n3joH68    381
# Name: second_category_id, dtype: int64

# %% [markdown]
# ## Furnishings

# %% [markdown]
# Furnishings has 4 third categories: File Cabinets, Magazine Holders, Shelving, Magazine Holders

# %%
random_assign_third_category(furniture, 
                            'Furnishings',
                            ['File Cabinets', 'Magazine Holders', 'Shelving','Magazine Holders'], 
                            [0.3, 0.4, 0.2, 0.1] )
# Out:
# Assigning third category ['File Cabinets', 'Magazine Holders', 'Shelving', 'Magazine Holders'] for second category, Furnishings
#
# Number of rows for Furnishings: 719
#
# third_category_name
# Magazine Holders    368
# File Cabinets       209
# Shelving            142
# dtype: int64
#
#
# third_category_id
# YK07LphIAao5    368
# iihlE9DOaPPG    209
# wrABaPay7bWc    142
# dtype: int64

# %% [markdown]
# ## Chairs

# %% [markdown]
# Chairs has 3 third categories: Office Chairs, Game Chairs, Stacking Chairs

# %%
random_assign_third_category(furniture, 
                            'Chairs',
                            ['Office Chairs', 'Game Chairs', 'Stacking Chairs'], 
                            [0.3, 0.5, 0.2] )
# Out:
# Assigning third category ['Office Chairs', 'Game Chairs', 'Stacking Chairs'] for second category, Chairs
#
# Number of rows for Chairs: 647
#
# third_category_name
# Game Chairs        319
# Office Chairs      214
# Stacking Chairs    114
# dtype: int64
#
#
# third_category_id
# 42mepTquRuAo    319
# JVAkT98IxHCr    214
# cn2Ru6EyCcMS    114
# dtype: int64

# %% [markdown]
# ## Bookcases

# %% [markdown]
# Bookcases has 4 third categories: Card Files, Cases & Holders, Desktop Organizers, Carts & Stands

# %%
random_assign_third_category(furniture, 
                            'Bookcases',
                            ['Card Files', 'Cases & Holders', 'Desktop Organizers', 'Carts & Stands'], 
                            [0.2, 0.3, 0.3, 0.2] )
# Out:
# Assigning third category ['Card Files', 'Cases & Holders', 'Desktop Organizers', 'Carts & Stands'] for second category, Bookcases
#
# Number of rows for Bookcases: 583
#
# third_category_name
# Desktop Organizers    172
# Cases & Holders       167
# Carts & Stands        130
# Card Files            114
# dtype: int64
#
#
# third_category_id
# F0RTA6ViSJS7    172
# itKSfJOXb5ua    167
# E5MdaVxCdRXK    130
# gUgpubVoW8ew    114
# dtype: int64

# %% [markdown]
# ## Tables

# %% [markdown]
# Tables has 3 third categories: Folding Tables, Office Desks and Accent & Coffee Tables

# %%
random_assign_third_category(furniture, 
                            'Tables',
                            ['Folding Tables', 'Office Desks','Accent & Coffee Tables'], 
                            [0.4, 0.3, 0.3] )
# Out:
# Assigning third category ['Folding Tables', 'Office Desks', 'Accent & Coffee Tables'] for second category, Tables
#
# Number of rows for Tables: 381
#
# third_category_name
# Folding Tables            148
# Office Desks              128
# Accent & Coffee Tables    105
# dtype: int64
#
#
# third_category_id
# AyKLpwQdYbZp    148
# dU9u9SAO1uPO    128
# PfeYajBaxsKf    105
# dtype: int64

# %%
furniture.head(10)
# Out:
#    product_id                                       product_name  \
# 4                                     Eldon Light Bulb, Duo Pack
# 7              Sauder Facets Collection Library, Sky Alder Fi...
# 12                               Advantus Photo Frame, Erganomic
# 24                           Safco Classic Bookcase, Traditional
# 27                              Novimex Swivel Fabric Task Chair
# 28                             Harbour Creations Bag Chairs, Red
# 29                                Office Star Rocking Chair, Red
# 32                       Global Deluxe High-Back Manager's Chair
# 34                  Bevis Round Conference Room Tables and Bases
# 36                         Harbour Creations Steel Folding Chair
#
#      category_id category_name second_category_id second_category_name  \
# 4   TQMnS5aEiOTt     Furniture       uJujcjmijtWM          Furnishings
# 7   TQMnS5aEiOTt     Furniture       QJq4Lp1JUP97            Bookcases
# 12  TQMnS5aEiOTt     Furniture       uJujcjmijtWM          Furnishings
# 24  TQMnS5aEiOTt     Furniture       QJq4Lp1JUP97            Bookcases
# 27  TQMnS5aEiOTt     Furniture       a90C0BfQbneg               Chairs
# 28  TQMnS5aEiOTt     Furniture       a90C0BfQbneg               Chairs
# 29  TQMnS5aEiOTt     Furniture       a90C0BfQbneg               Chairs
# 32  TQMnS5aEiOTt     Furniture       a90C0BfQbneg               Chairs
# 34  TQMnS5aEiOTt     Furniture       E2zR8n3joH68               Tables
# 36  TQMnS5aEiOTt     Furniture       a90C0BfQbneg               Chairs
#
#    third_category_id third_category_name  unit_price
# 4       wrABaPay7bWc            Shelving       25.26
# 7       itKSfJOXb5ua     Cases & Holders      170.98
# 12      YK07LphIAao5    Magazine Holders       51.60
# 24      F0RTA6ViSJS7  Desktop Organizers      438.15
# 27      42mepTquRuAo         Game Chairs      150.98
# 28      42mepTquRuAo         Game Chairs       61.62
# 29      42mepTquRuAo         Game Chairs      140.91
# 32      JVAkT98IxHCr       Office Chairs      285.98
# 34      AyKLpwQdYbZp      Folding Tables      179.29
# 36      42mepTquRuAo         Game Chairs       86.25

# %%
furniture.isnull().sum()
# Out:
# product_id              0
# product_name            0
# category_id             0
# category_name           0
# second_category_id      0
# second_category_name    0
# third_category_id       0
# third_category_name     0
# unit_price              0
# dtype: int64

# %% [markdown]
# # Technology

# %%
technology = deepcopy(data[data['category_name'] == 'Technology'])
technology.shape
# Out:
# (2484, 9)

# %%
technology.head(10)
# Out:
#    product_id                         product_name category_id category_name  \
# 6                   Brother Personal Copier, Laser                Technology
# 15                        Memorex Memory Card, USB                Technology
# 25                      Logitech Router, Erganomic                Technology
# 31                Panasonic Receipt Printer, White                Technology
# 33                   Sharp Fax Machine, High-Speed                Technology
# 39             Apple Speaker Phone, with Caller ID                Technology
# 41                           Konica Printer, White                Technology
# 45                            Belkin Keyboard, USB                Technology
# 46                 Cisco Signal Booster, Full Size                Technology
# 54              StarTech Receipt Printer, Wireless                Technology
#
#    second_category_id second_category_name third_category_id  \
# 6                                  Copiers
# 15                             Accessories
# 25                             Accessories
# 31                                Machines
# 33                                 Copiers
# 39                                  Phones
# 41                                Machines
# 45                             Accessories
# 46                                  Phones
# 54                                Machines
#
#    third_category_name  unit_price
# 6                           142.89
# 15                           68.32
# 25                          245.13
# 31                          119.31
# 33                          293.85
# 39                          123.30
# 41                          266.25
# 45                           84.09
# 46                          153.12
# 54                          110.58

# %%
technology['second_category_name'].value_counts()
# Out:
# Phones         733
# Accessories    700
# Copiers        537
# Machines       514
# Name: second_category_name, dtype: int64

# %%
technology.loc[:, 'category_id'] = nano_id()
technology.loc[technology['second_category_name'] == 'Phones', 'second_category_id'] = nano_id()
technology.loc[technology['second_category_name'] == 'Accessories', 'second_category_id'] = nano_id()
technology.loc[technology['second_category_name'] == 'Copiers', 'second_category_id'] = nano_id()
technology.loc[technology['second_category_name'] == 'Machines', 'second_category_id'] = nano_id()

# %%
technology['second_category_id'].value_counts()
# Out:
# UdyjL8htbIem    733
# Ia6gM6hxs1Ow    700
# O6uSgzSb85HK    537
# iXwl6cYOBkSZ    514
# Name: second_category_id, dtype: int64

# %%
technology.head(10)
# Out:
#    product_id                         product_name   category_id  \
# 6                   Brother Personal Copier, Laser  cI0l0hb5Knmv
# 15                        Memorex Memory Card, USB  cI0l0hb5Knmv
# 25                      Logitech Router, Erganomic  cI0l0hb5Knmv
# 31                Panasonic Receipt Printer, White  cI0l0hb5Knmv
# 33                   Sharp Fax Machine, High-Speed  cI0l0hb5Knmv
# 39             Apple Speaker Phone, with Caller ID  cI0l0hb5Knmv
# 41                           Konica Printer, White  cI0l0hb5Knmv
# 45                            Belkin Keyboard, USB  cI0l0hb5Knmv
# 46                 Cisco Signal Booster, Full Size  cI0l0hb5Knmv
# 54              StarTech Receipt Printer, Wireless  cI0l0hb5Knmv
#
#    category_name second_category_id second_category_name third_category_id  \
# 6     Technology       O6uSgzSb85HK              Copiers
# 15    Technology       Ia6gM6hxs1Ow          Accessories
# 25    Technology       Ia6gM6hxs1Ow          Accessories
# 31    Technology       iXwl6cYOBkSZ             Machines
# 33    Technology       O6uSgzSb85HK              Copiers
# 39    Technology       UdyjL8htbIem               Phones
# 41    Technology       iXwl6cYOBkSZ             Machines
# 45    Technology       Ia6gM6hxs1Ow          Accessories
# 46    Technology       UdyjL8htbIem               Phones
# 54    Technology       iXwl6cYOBkSZ             Machines
#
#    third_category_name  unit_price
# 6                           142.89
# 15                           68.32
# 25                          245.13
# 31                          119.31
# 33                          293.85
# 39                          123.30
# 41                          266.25
# 45                           84.09
# 46                          153.12
# 54                          110.58

# %% [markdown]
# ## Phones

# %% [markdown]
# Phone has 4 third categories: Office Phones, Landline Phones, Mobile Phones, Smartphones

# %%
random_assign_third_category(technology, 
                            'Phones',
                            ['Office Phones', 'Landline Phones', 'Mobile Phones', 'Smartphones'], 
                            [0.3, 0.2, 0.3, 0.2] )
# Out:
# Assigning third category ['Office Phones', 'Landline Phones', 'Mobile Phones', 'Smartphones'] for second category, Phones
#
# Number of rows for Phones: 733
#
# third_category_name
# Office Phones      226
# Mobile Phones      214
# Landline Phones    181
# Smartphones        112
# dtype: int64
#
#
# third_category_id
# LOYgbvPNm5UK    226
# kiI3QVPZx20S    214
# 7I8BWW492grp    181
# 04Bmug672M1i    112
# dtype: int64

# %% [markdown]
# ## Accessories

# %% [markdown]
# Accessories has 3 third categories: Mobile Accessories, Metworking & Wi-Fi, Hard Drives & Data Storage

# %%
random_assign_third_category(technology, 
                            'Accessories',
                            ['Mobile Accessories', 'Metworking & Wi-Fi', 'Hard Drives & Data Storage'], 
                            [0.3, 0.4, 0.3] )
# Out:
# Assigning third category ['Mobile Accessories', 'Metworking & Wi-Fi', 'Hard Drives & Data Storage'] for second category, Accessories
#
# Number of rows for Accessories: 700
#
# third_category_name
# Metworking & Wi-Fi            300
# Hard Drives & Data Storage    219
# Mobile Accessories            181
# dtype: int64
#
#
# third_category_id
# zH25BJILUbiu    300
# HEb20LvSltS6    219
# uAWgBRLwIEl1    181
# dtype: int64

# %% [markdown]
# ## Copiers

# %% [markdown]
# Copiers has 3 third categories: All-in-One Printers, Laser Printers, Inkjet Printers

# %%
random_assign_third_category(technology, 
                            'Copiers',
                            ['All-in-One Printers', 'Laser Printers', 'Inkjet Printers'], 
                            [0.2, 0.5, 0.3] )
# Out:
# Assigning third category ['All-in-One Printers', 'Laser Printers', 'Inkjet Printers'] for second category, Copiers
#
# Number of rows for Copiers: 537
#
# third_category_name
# Laser Printers         249
# Inkjet Printers        177
# All-in-One Printers    111
# dtype: int64
#
#
# third_category_id
# muJZOG51p9Pv    249
# cLhuwQSbME5n    177
# R3QMOyrkSbft    111
# dtype: int64

# %% [markdown]
# ## Machines

# %% [markdown]
# Machine has 3 third categories: Die Cutting, Fax Machines, Shredders

# %%
random_assign_third_category(technology, 
                            'Machines',
                            ['Die Cutting', 'Fax Machines', 'Shredders'], 
                            [0.2, 0.4, 0.4] )
# Out:
# Assigning third category ['Die Cutting', 'Fax Machines', 'Shredders'] for second category, Machines
#
# Number of rows for Machines: 514
#
# third_category_name
# Fax Machines    210
# Shredders       209
# Die Cutting      95
# dtype: int64
#
#
# third_category_id
# 06uQsYBqsU57    210
# kRNDYMvkwWTF    209
# tURn4OznViZs     95
# dtype: int64

# %%
technology.head(10)
# Out:
#    product_id                         product_name   category_id  \
# 6                   Brother Personal Copier, Laser  cI0l0hb5Knmv
# 15                        Memorex Memory Card, USB  cI0l0hb5Knmv
# 25                      Logitech Router, Erganomic  cI0l0hb5Knmv
# 31                Panasonic Receipt Printer, White  cI0l0hb5Knmv
# 33                   Sharp Fax Machine, High-Speed  cI0l0hb5Knmv
# 39             Apple Speaker Phone, with Caller ID  cI0l0hb5Knmv
# 41                           Konica Printer, White  cI0l0hb5Knmv
# 45                            Belkin Keyboard, USB  cI0l0hb5Knmv
# 46                 Cisco Signal Booster, Full Size  cI0l0hb5Knmv
# 54              StarTech Receipt Printer, Wireless  cI0l0hb5Knmv
#
#    category_name second_category_id second_category_name third_category_id  \
# 6     Technology       O6uSgzSb85HK              Copiers      muJZOG51p9Pv
# 15    Technology       Ia6gM6hxs1Ow          Accessories      zH25BJILUbiu
# 25    Technology       Ia6gM6hxs1Ow          Accessories      zH25BJILUbiu
# 31    Technology       iXwl6cYOBkSZ             Machines      kRNDYMvkwWTF
# 33    Technology       O6uSgzSb85HK              Copiers      muJZOG51p9Pv
# 39    Technology       UdyjL8htbIem               Phones      7I8BWW492grp
# 41    Technology       iXwl6cYOBkSZ             Machines      tURn4OznViZs
# 45    Technology       Ia6gM6hxs1Ow          Accessories      zH25BJILUbiu
# 46    Technology       UdyjL8htbIem               Phones      04Bmug672M1i
# 54    Technology       iXwl6cYOBkSZ             Machines      06uQsYBqsU57
#
#    third_category_name  unit_price
# 6       Laser Printers      142.89
# 15  Metworking & Wi-Fi       68.32
# 25  Metworking & Wi-Fi      245.13
# 31           Shredders      119.31
# 33      Laser Printers      293.85
# 39     Landline Phones      123.30
# 41         Die Cutting      266.25
# 45  Metworking & Wi-Fi       84.09
# 46         Smartphones      153.12
# 54        Fax Machines      110.58

# %%
technology.isnull().sum()
# Out:
# product_id              0
# product_name            0
# category_id             0
# category_name           0
# second_category_id      0
# second_category_name    0
# third_category_id       0
# third_category_name     0
# unit_price              0
# dtype: int64

# %%
result = pd.concat([office_supplies, furniture, technology])
result.shape
# Out:
# (10771, 9)

# %%
result.head(20)
# Out:
#    product_id                                 product_name   category_id  \
# 0                                      Tenex Lockers, Blue  O8xD8rO2X816
# 1                                 Acme Trimmer, High Speed  O8xD8rO2X816
# 2                                  Tenex Box, Single Width  O8xD8rO2X816
# 3                              Enermax Note Cards, Premium  O8xD8rO2X816
# 5                  Eaton Computer Printout Paper, 8.5 x 11  O8xD8rO2X816
# 8                             Fellowes Lockers, Wire Frame  O8xD8rO2X816
# 9                                Tenex Trays, Single Width  O8xD8rO2X816
# 10                          KitchenAid Coffee Grinder, Red  O8xD8rO2X816
# 11                     Hamilton Beach Refrigerator, Silver  O8xD8rO2X816
# 13             Binney & Smith Pencil Sharpener, Easy-Erase  O8xD8rO2X816
# 14                              Kleencut Ruler, High Speed  O8xD8rO2X816
# 16                   Sanford Pencil Sharpener, Water Color  O8xD8rO2X816
# 17               Wilson Jones Hole Reinforcements, Economy  O8xD8rO2X816
# 18                    Smead File Folder Labels, Adjustable  O8xD8rO2X816
# 19                      GlobeWeis Peel and Seal, Set of 50  O8xD8rO2X816
# 20                      Acco Hole Reinforcements, Recycled  O8xD8rO2X816
# 21                      Avery Hole Reinforcements, Durable  O8xD8rO2X816
# 22                 Wilson Jones Hole Reinforcements, Clear  O8xD8rO2X816
# 23                          Fellowes File Cart, Industrial  O8xD8rO2X816
# 26                           Hamilton Beach Toaster, Black  O8xD8rO2X816
#
#       category_name second_category_id second_category_name third_category_id  \
# 0   Office Supplies       e5a2vp9Bpczy              Storage      cGAY8PSjSybf
# 1   Office Supplies       KVraCWQHdXOj             Supplies      AABy1Yj6edjQ
# 2   Office Supplies       e5a2vp9Bpczy              Storage      cGAY8PSjSybf
# 3   Office Supplies       WtzhL5cVilg6                Paper      0V6sLr6aGtuU
# 5   Office Supplies       WtzhL5cVilg6                Paper      0V6sLr6aGtuU
# 8   Office Supplies       e5a2vp9Bpczy              Storage      jS5eFcAuwcyS
# 9   Office Supplies       e5a2vp9Bpczy              Storage      gm6nCZ8aVa3g
# 10  Office Supplies       hwpWTtn7Tl5o           Appliances      LoI4lmPulhq4
# 11  Office Supplies       hwpWTtn7Tl5o           Appliances      LoI4lmPulhq4
# 13  Office Supplies       iqGEIzIl1stw                  Art      sEghhe5Z1x5Z
# 14  Office Supplies       KVraCWQHdXOj             Supplies      AABy1Yj6edjQ
# 16  Office Supplies       iqGEIzIl1stw                  Art      8rDeNB23qEHt
# 17  Office Supplies       N5ccdFcsnltk              Binders      gCtco1vmTVuQ
# 18  Office Supplies       oCfS4bvy1LsH               Labels      SZidrffddp2x
# 19  Office Supplies       ZxKkOmS8NOKD            Envelopes      Hcw7hKx4Duob
# 20  Office Supplies       N5ccdFcsnltk              Binders      gCtco1vmTVuQ
# 21  Office Supplies       N5ccdFcsnltk              Binders      gCtco1vmTVuQ
# 22  Office Supplies       N5ccdFcsnltk              Binders      38rg4WcUvmop
# 23  Office Supplies       e5a2vp9Bpczy              Storage      jS5eFcAuwcyS
# 26  Office Supplies       hwpWTtn7Tl5o           Appliances      LoI4lmPulhq4
#
#        third_category_name  unit_price
# 0     Storage Bins & Boxes      204.15
# 1       Glue & Glue Sticks       44.58
# 2     Storage Bins & Boxes       16.53
# 3     Copy & Printer Paper       29.91
# 5     Copy & Printer Paper       30.69
# 8             File Folders      206.40
# 9             File Storage       54.24
# 10  Coffee, Water & Snacks       70.47
# 11  Coffee, Water & Snacks      333.92
# 13             Drawing Ink       27.93
# 14      Glue & Glue Sticks       13.56
# 16                   Chalk       26.10
# 17              A4 Binders        4.53
# 18                 Address        6.78
# 19                Business       21.39
# 20              A4 Binders        7.02
# 21              A4 Binders        5.91
# 22            Mini Binders        2.66
# 23            File Folders      137.79
# 26  Coffee, Water & Snacks       56.94

# %%
product_random_ids = result['product_id'].apply(lambda x: nano_id())

# %%
result.loc[:, 'product_id'] = product_random_ids

# %%
result.head(20)
# Out:
#       product_id                                 product_name   category_id  \
# 0   bguGYmIzBXeF                          Tenex Lockers, Blue  O8xD8rO2X816
# 1   bb4yPyycNt30                     Acme Trimmer, High Speed  O8xD8rO2X816
# 2   6frP11X2Lk5L                      Tenex Box, Single Width  O8xD8rO2X816
# 3   EffF7kN7qGHd                  Enermax Note Cards, Premium  O8xD8rO2X816
# 5   PlkqzI360PyP      Eaton Computer Printout Paper, 8.5 x 11  O8xD8rO2X816
# 8   gSawXTJpxRfr                 Fellowes Lockers, Wire Frame  O8xD8rO2X816
# 9   FNK4N0oBgIcn                    Tenex Trays, Single Width  O8xD8rO2X816
# 10  a8qliXBl9LNF               KitchenAid Coffee Grinder, Red  O8xD8rO2X816
# 11  9LzjfJNhM8t8          Hamilton Beach Refrigerator, Silver  O8xD8rO2X816
# 13  PXkHzXOTvTmo  Binney & Smith Pencil Sharpener, Easy-Erase  O8xD8rO2X816
# 14  NGfFlxY83Y3C                   Kleencut Ruler, High Speed  O8xD8rO2X816
# 16  3xjKo6b2Jtj2        Sanford Pencil Sharpener, Water Color  O8xD8rO2X816
# 17  Ju3xEHmjJPDt    Wilson Jones Hole Reinforcements, Economy  O8xD8rO2X816
# 18  D0YkD9j0SCi8         Smead File Folder Labels, Adjustable  O8xD8rO2X816
# 19  CwjTLJ6uB1ZS           GlobeWeis Peel and Seal, Set of 50  O8xD8rO2X816
# 20  MKiCZrC3fLU9           Acco Hole Reinforcements, Recycled  O8xD8rO2X816
# 21  LdgtYpSZKtpf           Avery Hole Reinforcements, Durable  O8xD8rO2X816
# 22  qY6EiFnw1jab      Wilson Jones Hole Reinforcements, Clear  O8xD8rO2X816
# 23  AfdXAP89rxDY               Fellowes File Cart, Industrial  O8xD8rO2X816
# 26  Xe8hn4ZYM19p                Hamilton Beach Toaster, Black  O8xD8rO2X816
#
#       category_name second_category_id second_category_name third_category_id  \
# 0   Office Supplies       e5a2vp9Bpczy              Storage      cGAY8PSjSybf
# 1   Office Supplies       KVraCWQHdXOj             Supplies      AABy1Yj6edjQ
# 2   Office Supplies       e5a2vp9Bpczy              Storage      cGAY8PSjSybf
# 3   Office Supplies       WtzhL5cVilg6                Paper      0V6sLr6aGtuU
# 5   Office Supplies       WtzhL5cVilg6                Paper      0V6sLr6aGtuU
# 8   Office Supplies       e5a2vp9Bpczy              Storage      jS5eFcAuwcyS
# 9   Office Supplies       e5a2vp9Bpczy              Storage      gm6nCZ8aVa3g
# 10  Office Supplies       hwpWTtn7Tl5o           Appliances      LoI4lmPulhq4
# 11  Office Supplies       hwpWTtn7Tl5o           Appliances      LoI4lmPulhq4
# 13  Office Supplies       iqGEIzIl1stw                  Art      sEghhe5Z1x5Z
# 14  Office Supplies       KVraCWQHdXOj             Supplies      AABy1Yj6edjQ
# 16  Office Supplies       iqGEIzIl1stw                  Art      8rDeNB23qEHt
# 17  Office Supplies       N5ccdFcsnltk              Binders      gCtco1vmTVuQ
# 18  Office Supplies       oCfS4bvy1LsH               Labels      SZidrffddp2x
# 19  Office Supplies       ZxKkOmS8NOKD            Envelopes      Hcw7hKx4Duob
# 20  Office Supplies       N5ccdFcsnltk              Binders      gCtco1vmTVuQ
# 21  Office Supplies       N5ccdFcsnltk              Binders      gCtco1vmTVuQ
# 22  Office Supplies       N5ccdFcsnltk              Binders      38rg4WcUvmop
# 23  Office Supplies       e5a2vp9Bpczy              Storage      jS5eFcAuwcyS
# 26  Office Supplies       hwpWTtn7Tl5o           Appliances      LoI4lmPulhq4
#
#        third_category_name  unit_price
# 0     Storage Bins & Boxes      204.15
# 1       Glue & Glue Sticks       44.58
# 2     Storage Bins & Boxes       16.53
# 3     Copy & Printer Paper       29.91
# 5     Copy & Printer Paper       30.69
# 8             File Folders      206.40
# 9             File Storage       54.24
# 10  Coffee, Water & Snacks       70.47
# 11  Coffee, Water & Snacks      333.92
# 13             Drawing Ink       27.93
# 14      Glue & Glue Sticks       13.56
# 16                   Chalk       26.10
# 17              A4 Binders        4.53
# 18                 Address        6.78
# 19                Business       21.39
# 20              A4 Binders        7.02
# 21              A4 Binders        5.91
# 22            Mini Binders        2.66
# 23            File Folders      137.79
# 26  Coffee, Water & Snacks       56.94

# %%
result.to_csv('../resource/data/fake_product_data.csv', index=False)
